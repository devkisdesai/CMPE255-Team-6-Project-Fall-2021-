# %%
# Import pacakages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import pycountry
import re
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets
import cufflinks as cf
import geopandas as gpd
from mpl_toolkits.axes_grid1 import make_axes_locatable

# %%
# load data
data_1960_2050 = pd.read_csv('./Datasets/Minimized Data 1960-2050.csv', low_memory=False)

# %%
# Clean/transform data
data_1960_2050.head(10)
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
# 5  Afghanistan          AFG
# 6  Afghanistan          AFG
# 7  Afghanistan          AFG
# 8  Afghanistan          AFG
# 9  Afghanistan          AFG
#
#                                          Series Name     Series Code  \
# 0  Age dependency ratio (% of working-age populat...     SP.POP.DPND
# 1                          Age dependency ratio, old  SP.POP.DPND.OL
# 2                        Age dependency ratio, young  SP.POP.DPND.YG
# 3                                      Net migration     SM.POP.NETM
# 4                  Number of deaths ages 10-14 years     SH.DTH.1014
# 5                  Number of deaths ages 15-19 years     SH.DTH.1519
# 6                  Number of deaths ages 20-24 years     SH.DTH.2024
# 7                    Number of deaths ages 5-9 years     SH.DTH.0509
# 8                            Number of infant deaths     SH.DTH.IMRT
# 9                    Number of infant deaths, female  SH.DTH.IMRT.FE
#
#       1960 [YR1960]     1961 [YR1961]     1962 [YR1962]     1963 [YR1963]  \
# 0   81.617265593364  82.6886781269233  83.2893702677964  83.6040745667416
# 1  5.08221355458813  5.13013875077877   5.1396410434319  5.11552596472367
# 2  76.5350520387758  77.5585393761445  78.1497292243645  78.4885486020179
# 3                ..                ..            -20000                ..
# 4                ..                ..                ..                ..
# 5                ..                ..                ..                ..
# 6                ..                ..                ..                ..
# 7                ..                ..                ..                ..
# 8                ..                ..                ..            106871
# 9                ..                ..                ..             49252
#
#       1964 [YR1964]     1965 [YR1965]  ...     2041 [YR2041]  \
# 0  83.8538402296331  84.1305132205961  ...   52.721641363705
# 1  5.06374943823744     4.98789855835  ...  6.22910451801117
# 2  78.7900907913956  79.1426146622461  ...  46.4925368456938
# 3                ..                ..  ...                ..
# 4                ..                ..  ...                ..
# 5                ..                ..  ...                ..
# 6                ..                ..  ...                ..
# 7                ..                ..  ...                ..
# 8            107406            107973  ...                ..
# 9             49519             49844  ...                ..
#
#       2042 [YR2042]     2043 [YR2043]     2044 [YR2044]     2045 [YR2045]  \
# 0  51.9732864237122  51.2542813990082  50.5649528551787   49.905272496857
# 1  6.38374301415072  6.54627153153927  6.71856043377268  6.90243289671151
# 2  45.5895434095615  44.7080098674689   43.846392421406  43.0028396001455
# 3           -311082                ..                ..                ..
# 4                ..                ..                ..                ..
# 5                ..                ..                ..                ..
# 6                ..                ..                ..                ..
# 7                ..                ..                ..                ..
# 8                ..                ..                ..                ..
# 9                ..                ..                ..                ..
#
#       2046 [YR2046]     2047 [YR2047]     2048 [YR2048]     2049 [YR2049]  \
# 0  49.3091701493759  48.7358507892608  48.1851513162138  47.6569146420521
# 1  7.10386591421077  7.31255821375793   7.5283209975396  7.74944602991995
# 2  42.2053042351651  41.4232925755029  40.6568303186742  39.9074686121321
# 3                ..           -310076                ..                ..
# 4                ..                ..                ..                ..
# 5                ..                ..                ..                ..
# 6                ..                ..                ..                ..
# 7                ..                ..                ..                ..
# 8                ..                ..                ..                ..
# 9                ..                ..                ..                ..
#
#       2050 [YR2050]
# 0  47.1525182056463
# 1  7.97648707408324
# 2  39.1760311315631
# 3                ..
# 4                ..
# 5                ..
# 6                ..
# 7                ..
# 8                ..
# 9                ..
#
# [10 rows x 95 columns]

# %%
# Patterns with missing data
# import missingno as msno
# msno.heatmap(data_1960_2050)

plt.figure(figsize=(10,6))
sns.heatmap(data_1960_2050.isnull().transpose(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Missing Data'})
plt.show()

# %%
# Removing Duplicated Fields
pop_data = data_1960_2050

i=1960
string =["Country_Name", "Country_Code", "Series_Name", "Series_Code"]
while i != 2051:
    temp = "[" + str(i) + "]"
    string.append(temp)
    i = i + 1
    
pop_data.columns = string

# replace .. with na
pop_data = pop_data.replace('..', np.nan)
pop_data = pop_data.set_index('Country_Name')

# %%
plt.figure(figsize=(10,6))
sns.heatmap(pop_data.isnull().transpose(),
            cmap="YlGnBu",
            cbar_kws={'label': 'Missing Data'})
plt.show()

# %%
pop_data.head()
# Out:
#              Country_Code                                        Series_Name  \
# Country_Name
# Afghanistan           AFG  Age dependency ratio (% of working-age populat...
# Afghanistan           AFG                          Age dependency ratio, old
# Afghanistan           AFG                        Age dependency ratio, young
# Afghanistan           AFG                                      Net migration
# Afghanistan           AFG                  Number of deaths ages 10-14 years
#
#                  Series_Code            [1960]            [1961]  \
# Country_Name
# Afghanistan      SP.POP.DPND   81.617265593364  82.6886781269233
# Afghanistan   SP.POP.DPND.OL  5.08221355458813  5.13013875077877
# Afghanistan   SP.POP.DPND.YG  76.5350520387758  77.5585393761445
# Afghanistan      SM.POP.NETM               NaN               NaN
# Afghanistan      SH.DTH.1014               NaN               NaN
#
#                         [1962]            [1963]            [1964]  \
# Country_Name
# Afghanistan   83.2893702677964  83.6040745667416  83.8538402296331
# Afghanistan    5.1396410434319  5.11552596472367  5.06374943823744
# Afghanistan   78.1497292243645  78.4885486020179  78.7900907913956
# Afghanistan             -20000               NaN               NaN
# Afghanistan                NaN               NaN               NaN
#
#                         [1965]            [1966]  ...            [2041]  \
# Country_Name                                      ...
# Afghanistan   84.1305132205961   85.337606639107  ...   52.721641363705
# Afghanistan      4.98789855835  5.03818379040036  ...  6.22910451801117
# Afghanistan   79.1426146622461  80.2994228487066  ...  46.4925368456938
# Afghanistan                NaN               NaN  ...               NaN
# Afghanistan                NaN               NaN  ...               NaN
#
#                         [2042]            [2043]            [2044]  \
# Country_Name
# Afghanistan   51.9732864237122  51.2542813990082  50.5649528551787
# Afghanistan   6.38374301415072  6.54627153153927  6.71856043377268
# Afghanistan   45.5895434095615  44.7080098674689   43.846392421406
# Afghanistan            -311082               NaN               NaN
# Afghanistan                NaN               NaN               NaN
#
#                         [2045]            [2046]            [2047]  \
# Country_Name
# Afghanistan    49.905272496857  49.3091701493759  48.7358507892608
# Afghanistan   6.90243289671151  7.10386591421077  7.31255821375793
# Afghanistan   43.0028396001455  42.2053042351651  41.4232925755029
# Afghanistan                NaN               NaN           -310076
# Afghanistan                NaN               NaN               NaN
#
#                         [2048]            [2049]            [2050]
# Country_Name
# Afghanistan   48.1851513162138  47.6569146420521  47.1525182056463
# Afghanistan    7.5283209975396  7.74944602991995  7.97648707408324
# Afghanistan   40.6568303186742  39.9074686121321  39.1760311315631
# Afghanistan                NaN               NaN               NaN
# Afghanistan                NaN               NaN               NaN
#
# [5 rows x 94 columns]

# %%
#list of country codes
country_codes = []
country_names = []
for country in pycountry.countries:
    country_codes.append(country.alpha_3)
    country_names.append(country.name)
country_codes.sort(key=str.lower)
country_names.sort(key=str.lower)

# %%
#countries data
countries_data = pop_data[pop_data.Country_Code.isin(country_codes)]
non_country_data = pop_data[~pop_data.Country_Code.isin(country_codes)]
# print(set(countries_data.Country_Name))
# print(set(non_country_data.Country_Name))
# no_data = (set(country_codes)) - set(countries_data.Country_Code)

# %%
#segment data

#totals
pop_migration = countries_data[countries_data.Series_Code == 'SM.POP.NETM'] #net migration
pop_total = countries_data[countries_data.Series_Code == 'SP.POP.TOTL'] #total population
pop_rural = countries_data[countries_data.Series_Code == 'SP.RUR.TOTL'] #rural population
pop_urban = countries_data[countries_data.Series_Code == 'SP.URB.TOTL'] #urban population

#world data
world_total = non_country_data[(non_country_data.Series_Code == "SP.POP.TOTL") & (non_country_data.Country_Code == "WLD")]
world_growth = non_country_data[(non_country_data.Series_Code == "SP.POP.GROW") & (non_country_data.Country_Code == "WLD")]
#ratios
pop_birth_rate = countries_data[countries_data.Series_Code == 'SP.DYN.CBRT.IN'] #Birth rate, crude (per 1,000 people)
pop_death_rate = countries_data[countries_data.Series_Code == 'SP.DYN.CDRT.IN'] #Death rate, crude (per 1,000 people)
pop_male = countries_data[countries_data.Series_Code == 'SP.POP.TOTL.MA.ZS'] #Population, male (% of total population)
pop_female = countries_data[countries_data.Series_Code == 'SP.POP.TOTL.FE.ZS'] #Population, female (% of total population)
pop_age_dependency_w = countries_data[countries_data.Series_Code == 'SP.POP.DPND'] #Age dependency ratio (% of working-age population)
pop_age_dependency_o = countries_data[countries_data.Series_Code == 'SP.POP.DPND.OL'] #Age dependency ratio, old
pop_age_dependency_y = countries_data[countries_data.Series_Code == 'SP.POP.DPND.YG'] #Age dependency ratio, young

# %%
#format data for visualizations
def format_data(df, names):
    columns = df.columns[4:]
    df = df.melt(value_vars=columns)
    df = df.rename(columns={"variable": names[0], "value": names[1]})
    df[names[0]] = df[names[0]].str.replace("[","")
    df[names[0]] = df[names[0]].str.replace("]","")
    df[names[1]]  = pd.to_numeric(df[names[1]], errors='coerce').fillna(0).astype(np.float64)
    return df

def preparePlot(dataframe): #We can use this method to plot individual plots (Can be expanded to be more automated)
    string = dataframe.index.tolist()
    dataframe = dataframe.T
    dataframe = dataframe.iloc[4:]
    dataframe = dataframe.astype('float64')
    dataframe.columns = string
    return dataframe


def pop_over_time_plot(country):
    pop_total_plot.loc[country].iplot(
                    xTitle='Year', 
                    yTitle='Population of {}'.format(country),
                    title='Population Over Time'
                     )
    
def pop_rural_over_time_plot(country):
    pop_rural_plot.loc[country].iplot(
                    xTitle='Year', 
                    yTitle='Population of {}'.format(country),
                    title='Rural Population Over Time'
                     )

def pop_urban_over_time_plot(country):
    pop_urban_plot.loc[country].iplot(
                    xTitle='Year', 
                    yTitle='Population of {}'.format(country),
                    title='Urban Population Over Time'
                     )

# %%
pop_total.head()
# Out:
#                Country_Code        Series_Name  Series_Code    [1960]  \
# Country_Name
# Afghanistan             AFG  Population, total  SP.POP.TOTL   8996967
# Albania                 ALB  Population, total  SP.POP.TOTL   1608800
# Algeria                 DZA  Population, total  SP.POP.TOTL  11057864
# American Samoa          ASM  Population, total  SP.POP.TOTL     20127
# Andorra                 AND  Population, total  SP.POP.TOTL     13410
#
#                   [1961]    [1962]    [1963]    [1964]    [1965]    [1966]  \
# Country_Name
# Afghanistan      9169406   9351442   9543200   9744772   9956318  10174840
# Albania          1659800   1711319   1762621   1814135   1864791   1914573
# Algeria         11336336  11619828  11912800  12221675  12550880  12902626
# American Samoa     20605     21246     22029     22850     23675     24473
# Andorra            14378     15379     16407     17466     18542     19646
#
#                 ...    [2041]    [2042]    [2043]    [2044]    [2045]  \
# Country_Name    ...
# Afghanistan     ...  57748000  58574000  59387000  60188000  60974000
# Albania         ...   2571000   2550000   2529000   2508000   2486000
# Algeria         ...  56174000  56711000  57250000  57789000  58326000
# American Samoa  ...     54000     54000     54000     54000     54000
# Andorra         ...     78000     78000     78000     77000     77000
#
#                   [2046]    [2047]    [2048]    [2049]    [2050]
# Country_Name
# Afghanistan     61746000  62503000  63245000  63972000  64683000
# Albania          2465000   2443000   2421000   2399000   2377000
# Algeria         58859000  59388000  59911000  60423000  60923000
# American Samoa     54000     54000     54000     54000     54000
# Andorra            77000     77000     77000     76000     76000
#
# [5 rows x 94 columns]

# %%
#world pop est
world_gpd = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))
world_gpd = world_gpd.merge(pop_total, left_on="iso_a3", right_on="Country_Code")

world_gpd.plot(column='pop_est', cmap='OrRd', legend=True);
# Out:
# C:\Users\GIGA\anaconda3\lib\site-packages\geopandas\array.py:85: ShapelyDeprecationWarning:
#
# __len__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Check the length of the `geoms` property instead to get the  number of parts of a multi-part geometry.
#
# C:\Users\GIGA\anaconda3\lib\site-packages\geopandas\plotting.py:38: ShapelyDeprecationWarning:
#
# Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#
# C:\Users\GIGA\anaconda3\lib\site-packages\descartes\patch.py:62: ShapelyDeprecationWarning:
#
# The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#
# C:\Users\GIGA\anaconda3\lib\site-packages\descartes\patch.py:64: ShapelyDeprecationWarning:
#
# The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.

# %%
# General visualizations - world population vs growth rate
world_total = format_data(world_total, ['year','population'])
world_growth = format_data(world_growth, ['year','growth'])
world_data = pd.merge(world_total, world_growth, on="year")

fig, ax = plt.subplots()

ax.plot(world_data['year'], world_data['population'], color='red')
ax.tick_params(axis='y', labelcolor='red')
ax2 = ax.twinx()

ax2.plot(world_data['year'], world_data['growth'], color='green')
ax2.tick_params(axis='y', labelcolor='green')
fig.autofmt_xdate(rotation=45)
ax.set_xticks(ax.get_xticks()[::5])
plt.show()
# Out:
# <ipython-input-11-cd77330632a8>:6: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#
# <ipython-input-11-cd77330632a8>:7: FutureWarning:
#
# The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.

# %%
# General visualizations - Migration Trends
migration_plot = preparePlot(pop_migration)
fig, axs = plt.subplots(figsize=(12, 4))  
migration_plot.plot.area(ax = axs, stacked = False)
axs.get_legend().remove()
axs.set_xlabel("Census Years")
axs.set_ylabel("Migration Trends")
axs.set_title("Net Migration by Country")

# %%
# General visualizations - Total Population of each country

cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)

pop_total_plot = pop_total.drop(columns=['Country_Code', 'Series_Name', 'Series_Code'])
interact(pop_over_time_plot, country=pop_total_plot.index)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.6.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# interactive(children=(Dropdown(description='country', options=('Afghanistan', 'Albania', 'Algeria', 'American …
# <function __main__.pop_over_time_plot(country)>

# %%
# General visualizations - Rural Population of each country
pop_rural_plot = pop_rural.drop(columns=['Country_Code', 'Series_Name', 'Series_Code'])
interact(pop_rural_over_time_plot, country=pop_rural_plot.index)
# Out:
# interactive(children=(Dropdown(description='country', options=('Afghanistan', 'Albania', 'Algeria', 'American …
# <function __main__.pop_rural_over_time_plot(country)>

# %%
pop_urban_plot = pop_urban.drop(columns=['Country_Code', 'Series_Name', 'Series_Code'])
interact(pop_urban_over_time_plot, country=pop_urban_plot.index)
# Out:
# interactive(children=(Dropdown(description='country', options=('Afghanistan', 'Albania', 'Algeria', 'American …
# <function __main__.pop_urban_over_time_plot(country)>

# %%
# General visualizations - male population vs female population
pop_male_plot = preparePlot(pop_male)
pop_female_plot = preparePlot(pop_female)

# %%
pop_male_plot.head(5)
# Out:
#         Afghanistan    Albania    Algeria  American Samoa  Andorra     Angola  \
# [1961]    51.587311  51.402612  50.244232             NaN      NaN  50.758741
# [1962]    51.500613  51.396377  50.220003             NaN      NaN  50.710194
# [1963]    51.419126  51.388691  50.195437             NaN      NaN  50.593929
# [1964]    51.342864  51.382340  50.177116             NaN      NaN  50.512812
# [1965]    51.271615  51.378538  50.169295             NaN      NaN  50.534826
#
#         Antigua and Barbuda  Argentina    Armenia      Aruba  ...    Uruguay  \
# [1961]            46.808472  50.387390  48.264175  49.034888  ...  49.996500
# [1962]            46.885352  50.331787  48.344434  49.034392  ...  49.959772
# [1963]            46.976244  50.275081  48.422398  49.013210  ...  49.925753
# [1964]            47.084541  50.219806  48.496133  48.987357  ...  49.893205
# [1965]            47.205233  50.167376  48.564339  48.975714  ...  49.861293
#
#         Uzbekistan    Vanuatu  Venezuela, RB    Vietnam  \
# [1961]   48.077912  51.509893      50.913439  49.443534
# [1962]   48.140878  51.394687      50.896397  49.455991
# [1963]   48.207480  51.303900      50.879070  49.467301
# [1964]   48.274858  51.296522      50.861187  49.476698
# [1965]   48.340979  51.420531      50.842325  49.483587
#
#         Virgin Islands (U.S.)  West Bank and Gaza  Yemen, Rep.     Zambia  \
# [1961]              49.661235           50.906130    49.948248  49.741493
# [1962]              49.759406           50.850850    49.912536  49.727125
# [1963]              49.865939           50.801967    49.872471  49.711720
# [1964]              49.942224           50.759502    49.818651  49.698387
# [1965]              50.013937           50.722985    49.745109  49.689312
#
#          Zimbabwe
# [1961]  49.861820
# [1962]  49.862114
# [1963]  49.862111
# [1964]  49.860624
# [1965]  49.857465
#
# [5 rows x 215 columns]

# %%
pop_male_plot.plot.line()
# Out:
# <AxesSubplot:>
